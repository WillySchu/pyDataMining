# %%
library(dplyr)
library(forecast)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: timeDate
# This is forecast 7.3

# %%
data = read.csv('travel_data.tsv', sep='\t')
head(data)
# Out:
#   ga.pagePath                        ga.date  ga.sessions
# 1 www.travelocity.com/flights-search 20170104 364537
# 2 www.travelocity.com/flights-search 20170105 332169
# 3 www.travelocity.com/flights-search 20161206 272280
# 4 www.travelocity.com/               20170103 268885
# 5 www.travelocity.com/flights-search 20170102 267440
# 6 www.travelocity.com/               20170104 266256

# %%
dates = data['ga.date']
head(dates)
# Out:
#   ga.date
# 1 20170104
# 2 20170105
# 3 20161206
# 4 20170103
# 5 20170102
# 6 20170104

# %%
# Out:
# The following objects are masked from data (pos = 3):
#
#     ga.date, ga.pagePath, ga.sessions
#
# The following objects are masked from data (pos = 4):
#
#     ga.date, ga.pagePath, ga.sessions
#      ga.pagePath
# 1    www.travelocity.com/flights-search
# 2    www.travelocity.com/flights-search
# 3    www.travelocity.com/flights-search
# 4    www.travelocity.com/
# 5    www.travelocity.com/flights-search
# 6    www.travelocity.com/
# 7    www.travelocity.com/flights-search
# 8    www.travelocity.com/
# 9    www.travelocity.com/flights-search
# 10   www.travelocity.com/flights-search
# 11   www.travelocity.com/flights-search
# 12   www.travelocity.com/flights-search
# 13   www.travelocity.com/
# 14   www.travelocity.com/
# 15   www.travelocity.com/flights-search
# 16   www.travelocity.com/flights-search
# 17   www.travelocity.com/flights-search
# 18   www.travelocity.com/
# 19   www.travelocity.com/
# 20   www.travelocity.com/
# 21   www.travelocity.com/flights-search
# 22   www.travelocity.com/flights-search
# 23   www.travelocity.com/
# 24   www.travelocity.com/flights-search
# 25   www.travelocity.com/
# 26   www.travelocity.com/
# 27   www.travelocity.com/
# 28   www.travelocity.com/
# 29   www.travelocity.com/
# 30   www.travelocity.com/flights-search
# ⋮    ⋮
# 971  www.travelocity.com/waterberg-district-hotels-kololo-game-reserve.h3501897.hotel-information
# 972  www.travelocity.com/all-inclusive
# 973  www.travelocity.com/checkouterror-flights
# 974  www.travelocity.com/destinations-in-florida.d211.flight-destinations
# 975  www.travelocity.com/destinations-in-hawaii.d213.flight-destinations
# 976  www.travelocity.com/las-vegas-hotels-the-venetian-resort-hotel-casino.h1443.hotel-information
# 977  www.travelocity.com/miami.d178286.destination-travel-guides
# 978  www.travelocity.com/pocono-manor-hotels-kalahari-resorts-conventions.h9525614.hotel-information
# 979  www.travelocity.com/bermuda-hotels-all-inclusive-hotel.0-0-d601715-tallinclusivehotel.travel-guide-filter-hotels
# 980  www.travelocity.com/cheap-flights-to-phoenix.d178298.travel-guide-flights
# 981  www.travelocity.com/las-vegas-hotels.d178276.travel-guide-hotels
# 982  www.travelocity.com/maui-island-hotels-all-inclusive-hotel.0-0-d180073-tallinclusivehotel.travel-guide-filter-hotels
# 983  www.travelocity.com/new-york.d178293.destination-travel-guides
# 984  www.travelocity.com/cancun.d179995.destination-travel-guides
# 985  www.travelocity.com/car-rentals-in-orlando.d178294.car-rental-guide
# 986  www.travelocity.com/las-vegas-hotels-ti-treasure-island-hotel-and-casino.h15930.hotel-information
# 987  www.travelocity.com/las-vegas-hotels.d178276.travel-guide-hotels
# 988  www.travelocity.com/new-york-hotels.d178293.travel-guide-hotels
# 989  www.travelocity.com/orlando-hotels-disneys-fort-wilderness-resort-campground.h14828.hotel-information
# 990  www.travelocity.com/riverside-hotels-the-mission-inn-hotel-spa.h15817.hotel-information
# 991  www.travelocity.com/walt-disney-world-resort.d6034120.destination-travel-guides
# 992  www.travelocity.com/cancun.d179995.destination-travel-guides
# 993  www.travelocity.com/g/c/lastminute
# 994  www.travelocity.com/g/rg/black-friday-cyber-monday-global
# 995  www.travelocity.com/las-vegas-hotels-ti-treasure-island-hotel-and-casino.h15930.hotel-information
# 996  www.travelocity.com/new-york-hotels.d178293.travel-guide-hotels
# 997  www.travelocity.com/orlando-hotels-disneys-fort-wilderness-resort-campground.h14828.hotel-information
# 998  www.travelocity.com/p/info-main/h_fw_default
# 999  www.travelocity.com/cheap-flights-to-bora-bora.d602861.travel-guide-flights
# 1000 www.travelocity.com/cheap-flights-to-bora-bora.d602861.travel-guide-flights

# %%
attach(sess)
sess = sess[order(ga.date),]
rownames(sess) = ga.date
sess$ga.pagePath = NULL
sess$ga.date = NULL
head(sess)
# Out:
# The following objects are masked from sess (pos = 3):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 4):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 5):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 6):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 7):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 8):
#
#     ga.date, ga.sessions
#
# The following objects are masked from sess (pos = 9):
#
#     ga.date, ga.sessions
#          ga.sessions
# 20161201 191696
# 20161202 170833
# 20161203 139675
# 20161204 177041
# 20161205 213344
# 20161206 211459

# %%
ga.sessions
# Out:
#  [1] 191696 170833 139675 177041 213344 211459 178916 154482 186320 188642
# [11] 175344 149314 133416 151347 177518 148920  94296 182264 268885 266256
# [21] 250454

# %%
plot(ga.sessions, type='o', col='blue')
# Out:
# plot without title

# %%
auto.arima(ga.sessions, stationary=FALSE, seasonal=TRUE)
# Out:
# Series: ga.sessions
# ARIMA(2,0,0) with non-zero mean
#
# Coefficients:
#          ar1      ar2   intercept
#       0.8882  -0.5701  180211.596
# s.e.  0.1785   0.1906    9331.881
#
# sigma^2 estimated as 929158670:  log likelihood=-245.59
# AIC=499.18   AICc=501.68   BIC=503.35

# %%
mod = Arima(ga.sessions, order=c(2, 0, 0))
plot(forecast(mod))
# Out:
# Plot with title “Forecasts from ARIMA(2,0,0) with non-zero mean”

# %%
df = data.frame(data)

# %%
df['ga.pagePath']
# Out:
#      ga.pagePath
# 1    www.travelocity.com/flights-search
# 2    www.travelocity.com/flights-search
# 3    www.travelocity.com/flights-search
# 4    www.travelocity.com/
# 5    www.travelocity.com/flights-search
# 6    www.travelocity.com/
# 7    www.travelocity.com/flights-search
# 8    www.travelocity.com/
